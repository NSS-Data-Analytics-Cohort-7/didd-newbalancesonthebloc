# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
eco_21_22_exit = pd.read_excel("../Data/TEIS-NSS Project Data 10-2022.xlsx", sheet_name="ECO with Exit21-22")
eco_21_22_exit.head()
# Out:
#   DISTRICT  CHILD_ID ECO_Entry_DATE  Ent SOCIAL_SCALE  Ent KNOWLEDGE_SCALE  \
# 0       ET  500335.0     2021-04-23               5.0                  3.0
# 1       ET  479453.0     2020-03-23               7.0                  7.0
# 2       ET  510663.0            NaT               NaN                  NaN
# 3       ET  452482.0     2019-01-31               2.0                  3.0
# 4       ET  506507.0            NaT               NaN                  NaN
#
#    Ent APPROPRIATE_ACTION_SCALE ECO_Exit_DATE  Exit SOCIAL_SCALE  \
# 0                           4.0    2021-10-23                6.0
# 1                           7.0    2021-08-19                7.0
# 2                           NaN           NaT                NaN
# 3                           3.0    2021-11-22                5.0
# 4                           NaN           NaT                NaN
#
#    Exit KNOWLEDGE_SCALE  Exit APPROPRIATE_ACTION_SCALE  ... OC2 Data Check  \
# ...

# %%
eco_21_22_data = pd.read_excel("../Data/TEIS-NSS Project Data 10-2022.xlsx", sheet_name="Elig Timeline Rpt 2018-2022")
eco_21_22_data.head()
# Out:
#   District  Child ID Child Status  Child Phase Init. IFSP Due Date  \
# 0       ET    453926     Inactive         IFSP          2019-03-04
# 1       ET    431729     Inactive         IFSP          2018-10-26
# 2       ET    462474     Inactive         IFSP          2019-06-28
# 3       ET    446841     Inactive  Eligibility          2018-11-23
# 4       ET    459629     Inactive         IFSP          2019-05-16
#
#   IFSP Due Date IFSP Late Reason Active Ref. Date Parent Consent/Intake Date  \
# 0    2019-03-27           System       2019-01-18                 2019-02-04
# 1    2018-10-26              NaN       2018-09-11                 2018-09-25
# 2    2019-06-14              NaN       2019-05-14                 2019-05-30
# 3           NaT              NaN       2018-10-09                 2018-10-25
# 4    2019-04-24              NaN       2019-04-01                 2019-04-10
#
#   Date Dev. Evaluator Rec'd. Ref.  ... # Days Parent Consent to Dev. Eval.  \
# ...

# %%
df = pd.merge(eco_21_22_exit, eco_21_22_data, how='left', left_on = 'CHILD_ID', right_on = 'Child ID')

# %%
df.head()
# Out:
#   DISTRICT  CHILD_ID ECO_Entry_DATE  Ent SOCIAL_SCALE  Ent KNOWLEDGE_SCALE  \
# 0       ET  500335.0     2021-04-23               5.0                  3.0
# 1       ET  479453.0     2020-03-23               7.0                  7.0
# 2       ET  510663.0            NaT               NaN                  NaN
# 3       ET  452482.0     2019-01-31               2.0                  3.0
# 4       ET  506507.0            NaT               NaN                  NaN
#
#    Ent APPROPRIATE_ACTION_SCALE ECO_Exit_DATE  Exit SOCIAL_SCALE  \
# 0                           4.0    2021-10-23                6.0
# 1                           7.0    2021-08-19                7.0
# 2                           NaN           NaT                NaN
# 3                           3.0    2021-11-22                5.0
# 4                           NaN           NaT                NaN
#
#    Exit KNOWLEDGE_SCALE  Exit APPROPRIATE_ACTION_SCALE  ...  \
# ...

# %%
narrow_df = df[['Init. Elig. Category','DISTRICT', 'CHILD_ID', 'Ent SOCIAL_SCALE', 'Ent KNOWLEDGE_SCALE', 'Ent APPROPRIATE_ACTION_SCALE', 'Exit SOCIAL_SCALE', 'Exit KNOWLEDGE_SCALE', 'Exit APPROPRIATE_ACTION_SCALE', 'ECO_Entry_DATE', 'ECO_Exit_DATE', '<Calc> Day count']]

# %%
narrow_df.head()
# Out:
#        Init. Elig. Category DISTRICT  CHILD_ID  Ent SOCIAL_SCALE  \
# 0  Developmental Evaluation       ET  500335.0               5.0
# 1  Developmental Evaluation       ET  479453.0               7.0
# 2  Developmental Evaluation       ET  510663.0               NaN
# 3  Developmental Evaluation       ET  452482.0               2.0
# 4  Developmental Evaluation       ET  506507.0               NaN
#
#    Ent KNOWLEDGE_SCALE  Ent APPROPRIATE_ACTION_SCALE  Exit SOCIAL_SCALE  \
# 0                  3.0                           4.0                6.0
# 1                  7.0                           7.0                7.0
# 2                  NaN                           NaN                NaN
# 3                  3.0                           3.0                5.0
# 4                  NaN                           NaN                NaN
#
#    Exit KNOWLEDGE_SCALE  Exit APPROPRIATE_ACTION_SCALE ECO_Entry_DATE  \
# ...

# %% [markdown]
# ###narrow_df = narrow_df.fillna(0)
# narrow_df.head()

# %%
narrow_df = narrow_df.dropna()
narrow_df.head()
# Out:
#        Init. Elig. Category DISTRICT  CHILD_ID  Ent SOCIAL_SCALE  \
# 0  Developmental Evaluation       ET  500335.0               5.0
# 1  Developmental Evaluation       ET  479453.0               7.0
# 3  Developmental Evaluation       ET  452482.0               2.0
# 5  Developmental Evaluation       ET  494216.0               2.0
# 6  Developmental Evaluation       ET  449725.0               4.0
#
#    Ent KNOWLEDGE_SCALE  Ent APPROPRIATE_ACTION_SCALE  Exit SOCIAL_SCALE  \
# 0                  3.0                           4.0                6.0
# 1                  7.0                           7.0                7.0
# 3                  3.0                           3.0                5.0
# 5                  4.0                           6.0                4.0
# 6                  5.0                           7.0                7.0
#
#    Exit KNOWLEDGE_SCALE  Exit APPROPRIATE_ACTION_SCALE ECO_Entry_DATE  \
# ...

# %%
narrow_df = narrow_df.loc[(narrow_df['<Calc> Day count'] >= 180)]
narrow_df.head()
# Out:
#        Init. Elig. Category DISTRICT  CHILD_ID  Ent SOCIAL_SCALE  \
# 0  Developmental Evaluation       ET  500335.0               5.0
# 1  Developmental Evaluation       ET  479453.0               7.0
# 3  Developmental Evaluation       ET  452482.0               2.0
# 6  Developmental Evaluation       ET  449725.0               4.0
# 7  Developmental Evaluation       ET  494502.0               6.0
#
#    Ent KNOWLEDGE_SCALE  Ent APPROPRIATE_ACTION_SCALE  Exit SOCIAL_SCALE  \
# 0                  3.0                           4.0                6.0
# 1                  7.0                           7.0                7.0
# 3                  3.0                           3.0                5.0
# 6                  5.0                           7.0                7.0
# 7                  4.0                           5.0                7.0
#
#    Exit KNOWLEDGE_SCALE  Exit APPROPRIATE_ACTION_SCALE ECO_Entry_DATE  \
# ...

# %% [markdown]
# ###test
